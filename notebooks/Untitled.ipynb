# %%
import bmosantos.wavelib as wave
# %load_ext autoreload
# %autoreload 2

# %%
import bmosantos.lib as lib

# %%
lib.get_data('d-bqq4Fx4pjuztAPQkYS')
# Out:
#               date_time      lat      lon  battery  compass    rh  flag_rh  \
# 118 2022-03-20 00:00:00 -22.8199 -40.0969     12.8      139  71.3        0
# 117 2022-03-20 01:00:00 -22.8197 -40.0969     12.7      139  73.8        0
# 116 2022-03-20 02:00:00 -22.8197 -40.0967     12.8      137  72.9        0
# 115 2022-03-20 03:00:00 -22.8194 -40.0967     12.8      145  74.1        0
# 114 2022-03-20 04:00:00 -22.8192 -40.0963     12.7      121  74.1        0
# ..                  ...      ...      ...      ...      ...   ...      ...
# 4   2022-03-24 19:00:00 -22.8185 -40.1011     13.6      121  63.4        0
# 3   2022-03-24 20:00:00 -22.8187 -40.1009     13.4      141  62.0        0
# 2   2022-03-24 21:00:00 -22.8188 -40.1008     12.8      151  61.1        0
# 1   2022-03-24 22:00:00 -22.8187 -40.1009     12.8      131  65.0        0
# 0   2022-03-24 23:00:00 -22.8187 -40.1011     12.8      165  66.2        0
#
#        pres  flag_pres  atmp  ...   tp1  flag_tp1   tp2  flag_tp2  wvdir1  \
# 118  1014.7          0  27.5  ...   7.4         0   7.1         0      63
# 117  1014.3          0  27.5  ...   5.7         0   6.4         0      60
# 116  1015.1          0  27.6  ...   5.9         0   7.5         0      58
# 115  1014.6          0  27.5  ...   7.4         0   7.3         0      54
# 114  1014.3          0  27.4  ...   7.1         0   6.7         0      53
# ..      ...        ...   ...  ...   ...       ...   ...       ...     ...
# 4    1015.5          0  27.1  ...  11.8         0  12.2         0     144
# 3    1015.2          0  27.1  ...  11.8         0  12.2         0     144
# 2    1015.7          0  27.0  ...  13.3         0  12.8         0     145
# 1    1015.6          0  26.9  ...  12.5         0  12.2         0     149
# 0    1016.3          0  26.9  ...  11.8         0  12.2         0     148
#
#      flag_wvdir1  wvdir2  flag_wvdir2  wvspread1  flag_wvspread1
# 118            0    63.0            0         40               0
# 117            0    63.0            0         40               0
# 116            0    58.0            0         39               0
# 115            0    42.0            0         39               0
# 114            0    51.0            0         40               0
# ..           ...     ...          ...        ...             ...
# 4              0   153.0            0         32               0
# 3              0   138.0            0         31               0
# 2              0   155.0            0         30               0
# 1              0   134.0            0         27               0
# 0              0   144.0            0         29               0
#
# [119 rows x 51 columns]

# %%
df = lib.get_data('d-bqq4Fx4pjuztAPQkYS')

# %%
df['date_time'].min().strftime('%d-%m-%Y %X')
# Out:
# '20-03-2022 00:00:00'

# %%
wave.get_data('rCsdguPf76exUsqLYxuY')
# Out:
# > /home/soutobias/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py(57)create_norm()
#      55     for index, row in df.iterrows():
#      56         breakpoint()
# ---> 57         if row['date_time'].hour % 3 == 0:
#      58             wvd  = np.arange(row['wvdir'] - 4.75, row['wvdir'] + 4.75, 0.4)
#      59             ener = norm.pdf(np.arange(-11,11 , 1),0,4.7) * row['energy'] * 80
#
# ipdb> row['date_time'].hour
# 0
# ipdb> row['date_time'].hour % 3 == 0
# True
# ipdb> exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-11-e2169154c349> in <module>
# ----> 1 wave.get_data('rCsdguPf76exUsqLYxuY')
#
# ~/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py in get_data(token)
#      18     df = adjust_data(df.copy())
#      19
# ---> 20     df = create_norm(df.copy())
#      21
#      22     return df
#
# ~/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py in create_norm(df)
#      55     for index, row in df.iterrows():
#      56         breakpoint()
# ---> 57         if row['date_time'].hour % 3 == 0:
#      58             wvd  = np.arange(row['wvdir'] - 4.75, row['wvdir'] + 4.75, 0.4)
#      59             ener = norm.pdf(np.arange(-11,11 , 1),0,4.7) * row['energy'] * 80
#
# ~/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py in create_norm(df)
#      55     for index, row in df.iterrows():
#      56         breakpoint()
# ---> 57         if row['date_time'].hour % 3 == 0:
#      58             wvd  = np.arange(row['wvdir'] - 4.75, row['wvdir'] + 4.75, 0.4)
#      59             ener = norm.pdf(np.arange(-11,11 , 1),0,4.7) * row['energy'] * 80
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:
