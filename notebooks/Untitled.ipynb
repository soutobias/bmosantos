# %%
import bmosantos.wavelib as wave
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import bmosantos.lib as lib

# %%
lib.get_data('d-bqq4Fx4pjuztAPQkYS')
# Out:
# http://remobsapi.herokuapp.com/api/v1/data_buoys?buoy=22&start_date=2022-02-03&end_date=2022-02-08&token=d-bqq4Fx4pjuztAPQkYS
#        id  buoy_id      lat      lon                 date_time  battery  \
# 0    8982       22 -22.8637 -40.1527  2022-02-07T12:00:00.000Z     13.7
# 1    8981       22 -22.8791 -40.1689  2022-02-07T11:00:00.000Z     13.2
# 2    8980       22 -22.8836 -40.1674  2022-02-07T10:00:00.000Z     12.9
# 3    8979       22 -22.8571 -40.1358  2022-02-07T09:00:00.000Z     12.8
# 4    8978       22 -22.8814 -40.1690  2022-02-07T08:00:00.000Z     12.6
# ..    ...      ...      ...      ...                       ...      ...
# 103  8879       22 -22.8848 -43.1355  2022-02-03T04:00:00.000Z     12.7
# 104  8878       22 -22.8848 -43.1356  2022-02-03T03:00:00.000Z     12.7
# 105  8877       22 -22.8848 -43.1356  2022-02-03T02:00:00.000Z     12.7
# 106  8876       22 -22.8848 -43.1355  2022-02-03T01:00:00.000Z     12.7
# ...

# %%
df = lib.get_data('rCsdguPf76exUsqLYxuY')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 df = lib.get_data('rCsdguPf76exUsqLYxuY')
#
# File ~/code/soutobias/personal_codes/remobs/bmosantos/bmosantos/lib.py:20, in get_data(token)
#      17 url=f'http://remobsapi.herokuapp.com/api/v1/data_buoys?buoy=22&start_date={start_time}&end_date={time_now}&token={token}'
#      19 response = requests.get(url).json()
# ---> 20 df = pd.DataFrame(response)
#      21 for i in df.columns:
#      22     try:
#
# File ~/.pyenv/versions/3.8.6/envs/bmosantos/lib/python3.8/site-packages/pandas/core/frame.py:637, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     631     mgr = self._init_mgr(
#     632         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     633     )
#     635 elif isinstance(data, dict):
# ...

# %%
wave.get_data('rCsdguPf76exUsqLYxuY')
# Out:
# > /home/soutobias/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py(57)create_norm()
#      55     for index, row in df.iterrows():
#      56         breakpoint()
# ---> 57         if row['date_time'].hour % 3 == 0:
#      58             wvd  = np.arange(row['wvdir'] - 4.75, row['wvdir'] + 4.75, 0.4)
#      59             ener = norm.pdf(np.arange(-11,11 , 1),0,4.7) * row['energy'] * 80
#
# ipdb> row['date_time'].hour
# 0
# ipdb> row['date_time'].hour % 3 == 0
# True
# ipdb> exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-11-e2169154c349> in <module>
# ----> 1 wave.get_data('rCsdguPf76exUsqLYxuY')
#
# ~/code/soutobias/soutobias_codes/bmosantos/bmosantos/wavelib.py in get_data(token)
#      18     df = adjust_data(df.copy())
#      19
# ---> 20     df = create_norm(df.copy())
#      21
#      22     return df
#
# ...
